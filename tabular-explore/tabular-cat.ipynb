# %%
import pandas as pd
import numpy as np

# %%
datapath = 'data/'
demo = pd.read_csv(datapath + 'Demographics.csv')
icd = pd.read_csv(datapath + 'ICD.csv')
lab = pd.read_csv(datapath + 'LABS.csv')
vitals = pd.read_csv(datapath + 'Vitals.csv')
inpmed = pd.read_csv(datapath + 'INP_MED.csv')
outmed = pd.read_csv(datapath + 'OUT_MED.csv')
label = pd.read_csv(datapath + 'Labels.csv')

# %% [markdown]
# # Check consistency

# %%
print(label[label['split'] == 'val'])
# Out:
#       Unnamed: 0   idx  label       pe_type split
# 2              2  2738      0           NaN   val
# 11            11  2000      1       central   val
# 37            37   781      1       central   val
# 52            52   288      1  subsegmental   val
# 68            68   315      0           NaN   val
# ...          ...   ...    ...           ...   ...
# 1810        1810  1911      0           NaN   val
# 1822        1822  1425      0           NaN   val
# 1823        1823  1893      1     segmental   val
# 1829        1829   128      1       central   val
# 1833        1833   127      0           NaN   val
#
# [193 rows x 5 columns]

# %%
print(demo[demo['idx'] == 2738])
# Out:
#     current_age_yrs  Female  Male  Asian  Black  Native American  Other  \
# 37            78.95       1     0      0      0                0      0
#
#     Pacific Islander  Unknown_race  White  SMOKER_N  SMOKER_Y   idx split
# 37                 0             1      0         1         0  2738   val

# %% [markdown]
# # Combine

# %%
combined_df = demo

for df in [icd, lab, vitals, label, inpmed, outmed]:
    combined_df = combined_df.merge(df, on='idx', how='outer', suffixes=('', '_duplicate'))

columns_to_drop = [col for col in combined_df.columns if '_duplicate' in col]
combined_df.drop(columns=columns_to_drop, inplace=True)

# %%
combined_df
# Out:
#       current_age_yrs  Female  Male  Asian  Black  Native American  Other  \
# 0               80.00       1     0      0      0                0      0
# 1               64.12       0     1      0      0                0      0
# 2               93.42       0     1      0      0                0      0
# 3               93.82       1     0      0      0                0      0
# 4               71.78       1     0      0      0                0      0
# ...               ...     ...   ...    ...    ...              ...    ...
# 4257            81.29       1     0      0      0                0      0
# 4258            81.29       1     0      0      0                0      0
# 4259            81.29       1     0      0      0                0      0
# 4260            81.29       1     0      0      0                0      0
# 4261            81.29       1     0      0      0                0      0
#
#       Pacific Islander  Unknown_race  White  ...  \
# 0                    0             0      1  ...
# 1                    0             0      1  ...
# 2                    0             0      1  ...
# 3                    0             0      1  ...
# 4                    0             0      1  ...
# ...                ...           ...    ...  ...
# 4257                 0             0      1  ...
# 4258                 0             0      1  ...
# 4259                 0             0      1  ...
# 4260                 0             0      1  ...
# 4261                 0             0      1  ...
#
#       Outpatient_LHRH(GNRH)AGNST PIT.SUP-CENTRAL PRECOCIOUS PUBERTY:Frequeny  \
# 0                                                     0
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 4257                                                  0
# 4258                                                  0
# 4259                                                  0
# 4260                                                  0
# 4261                                                  0
#
#       Outpatient_THROMBOLYTIC - NUCLEOTIDE TYPE:Frequeny  \
# 0                                                     0
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 4257                                                  0
# 4258                                                  0
# 4259                                                  0
# 4260                                                  0
# 4261                                                  0
#
#       Outpatient_SELECTIVE SEROTONIN 5-HT2A INVERSE AGONISTS (SSIA):Frequeny  \
# 0                                                     0
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 4257                                                  0
# 4258                                                  0
# 4259                                                  0
# 4260                                                  0
# 4261                                                  0
#
#      Outpatient_ANTINEOPLASTIC - HEDGEHOG PATHWAY INHIBITOR:Frequeny  \
# 0                                                     0
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 4257                                                  0
# 4258                                                  0
# 4259                                                  0
# 4260                                                  0
# 4261                                                  0
#
#       Outpatient_ORGAN TRANSPLANTATION PRESERVATION SOLUTIONS:Frequeny  \
# 0                                                     0
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 4257                                                  0
# 4258                                                  0
# 4259                                                  0
# 4260                                                  0
# 4261                                                  0
#
#       Outpatient_FEEDING DEVICES:Frequeny  \
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       0
# 4                                       0
# ...                                   ...
# 4257                                    0
# 4258                                    0
# 4259                                    0
# 4260                                    0
# 4261                                    0
#
#       Outpatient_DRUGS TO TX GAUCHER DX-TYPE 1, SUBSTRATE REDUCING:Frequeny  \
# 0                                                     0
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 4257                                                  0
# 4258                                                  0
# 4259                                                  0
# 4260                                                  0
# 4261                                                  0
#
#       Outpatient_TOPICAL PREPARATIONS,NON-MEDICINAL:Frequeny  \
# 0                                                     0
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 4257                                                  0
# 4258                                                  0
# 4259                                                  0
# 4260                                                  0
# 4261                                                  0
#
#       Outpatient_ANTI-INFLAMMATORY, INTERLEUKIN-1 BETA BLOCKERS:Frequeny  \
# 0                                                     0
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 4257                                                  0
# 4258                                                  0
# 4259                                                  0
# 4260                                                  0
# 4261                                                  0
#
#       Outpatient_ACNE AGENTS,SYSTEMIC:Frequeny
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
# ...                                        ...
# 4257                                         0
# 4258                                         0
# 4259                                         0
# 4260                                         0
# 4261                                         0
#
# [4262 rows x 2915 columns]

# %%
non_integer_columns = combined_df.columns[combined_df.applymap(lambda x: not isinstance(x, (int, float))).any()]
print(non_integer_columns)
# Out:
# Index(['split', 'pe_type'], dtype='object')

# %%
split_label = combined_df[['idx', 'pe_type', 'split']]

# %% [markdown]
# # PCA

# %%
pcadata = combined_df.drop(columns=['pe_type', 'split'])

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(pcadata)

pca = PCA()
pca.fit(scaled_data)

loadings = pca.components_.T
feature_importances = (loadings ** 2).sum(axis=1)
top_features_idx = feature_importances.argsort()[::-1][:200]
df_top_features = pcadata.iloc[:, top_features_idx]

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(pcadata)

pca = PCA()
principal_components = pca.fit_transform(scaled_data)

# %%
explained_variance = pca.explained_variance_ratio_
cumulative_variance = np.cumsum(explained_variance)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))

# Plotting individual explained variance
plt.bar(range(len(explained_variance)), explained_variance, alpha=0.5, align='center', label='Individual explained variance')
plt.step(range(len(cumulative_variance)), cumulative_variance, where='mid', label='Cumulative explained variance')

plt.ylabel('Explained variance ratio')
plt.xlabel('Principal components')
plt.legend(loc='best')
plt.tight_layout()
plt.show()

# %%
pca_df = pd.DataFrame(data=principal_components, columns=[f'PC{i}' for i in range(1, len(pca.explained_variance_)+1)])

# %%
pca_df
# Out:
#             PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0     17.097325  7.641927  0.533709 -5.907475 -1.285043  6.153636  1.301839
# 1     -8.396764 -1.447397  0.988547 -0.385877  1.867741 -0.168004 -1.041959
# 2     -4.905358  0.520423  0.336167 -1.095286  0.420959 -0.801398 -0.603331
# 3     -7.300688 -0.905922  0.787745 -0.529478  1.438142  0.141928 -0.385910
# 4     -8.231640 -1.060502  0.808289 -0.351696  1.779599  0.322029 -0.550090
# ...         ...       ...       ...       ...       ...       ...       ...
# 4257  -5.885670 -0.379419  0.559674 -0.849048  0.950462  0.088025 -0.050225
# 4258  -5.885670 -0.379419  0.559674 -0.849048  0.950462  0.088025 -0.050225
# 4259  -5.885670 -0.379419  0.559674 -0.849048  0.950462  0.088025 -0.050225
# 4260  -5.885670 -0.379419  0.559674 -0.849048  0.950462  0.088025 -0.050225
# 4261  -5.885670 -0.379419  0.559674 -0.849048  0.950462  0.088025 -0.050225
#
#            PC8       PC9      PC10  ...        PC2904        PC2905  \
# 0    -1.628554 -4.558714  9.044674  ... -2.130916e-18 -8.114878e-19
# 1    -0.557644 -0.797503 -1.938291  ... -1.747278e-17 -1.151972e-17
# 2     0.407507  0.179527  0.833639  ...  2.035141e-17 -9.070230e-19
# 3    -0.350930 -0.481913 -0.796252  ... -7.811128e-18 -2.788681e-17
# 4    -0.366957 -0.890611 -1.538282  ... -2.262224e-17 -7.748824e-17
# ...        ...       ...       ...  ...           ...           ...
# 4257  0.204485 -0.239207 -0.052659  ... -6.037712e-17  3.659381e-17
# 4258  0.204485 -0.239207 -0.052659  ... -6.037712e-17  3.659381e-17
# 4259  0.204485 -0.239207 -0.052659  ...  4.956124e-17 -3.748915e-17
# 4260  0.204485 -0.239207 -0.052659  ...  7.464443e-17 -1.976730e-16
# 4261  0.204485 -0.239207 -0.052659  ... -1.382783e-16 -1.447089e-16
#
#             PC2906        PC2907        PC2908        PC2909        PC2910  \
# 0    -1.906705e-18 -4.451614e-19 -1.691966e-18  2.787999e-19  2.394379e-19
# 1    -3.431054e-17  1.971290e-17  9.490557e-18 -9.272716e-18  1.454635e-17
# 2     3.628396e-17 -7.475951e-19  6.451994e-19  3.896582e-18 -3.969265e-18
# 3    -2.406175e-17 -2.427867e-17  1.787078e-18  2.716795e-18 -3.562210e-18
# 4    -6.001485e-17 -2.110831e-19 -3.848324e-18 -5.281873e-18  4.521327e-18
# ...            ...           ...           ...           ...           ...
# 4257 -3.201277e-17  5.325079e-17 -4.713359e-18  2.061821e-17  1.385418e-17
# 4258 -3.201277e-17  5.325079e-17 -4.713359e-18  2.061821e-17  1.385418e-17
# 4259 -5.255465e-17 -1.039009e-16  1.417734e-16 -2.426145e-16 -1.177974e-16
# 4260 -9.900423e-17 -5.369880e-17  1.058982e-17 -1.059098e-16 -1.112056e-16
# 4261  3.286271e-17 -1.399621e-16  1.151726e-16 -2.688414e-16 -9.494821e-17
#
#             PC2911        PC2912        PC2913
# 0     1.448225e-19  1.187687e-19 -9.329431e-20
# 1    -1.898253e-18 -3.134921e-18  4.830946e-18
# 2    -1.611076e-18  2.933449e-18  6.066994e-19
# 3    -4.794698e-18  5.567068e-19 -1.560329e-18
# 4     4.845232e-19 -1.520127e-18  4.693363e-18
# ...            ...           ...           ...
# 4257 -1.759010e-17 -1.047412e-18  6.086172e-18
# 4258 -1.759010e-17 -1.047412e-18  6.086172e-18
# 4259 -1.158963e-17 -2.232152e-17  3.212981e-17
# 4260  1.196240e-16  2.351697e-17 -3.774871e-17
# 4261  1.291575e-16  2.279735e-17  8.676774e-18
#
# [4262 rows x 2913 columns]

# %%
loadings = pca.components_
plt.figure(figsize=(10,5))
plt.bar(range(len(loadings[0])), loadings[0])
plt.xlabel('Original Feature Index')
plt.ylabel('Loading Value')
plt.title('Loadings for Principal Component 1')
plt.show()

# %% [markdown]
# # XGBOOOOOOST

# %%
pe_type_mapping = {
    'segmental': 1,
    'central': 1,
    'subsegmental': 1
}

split_label.loc[:, 'pe_type'] = split_label['pe_type'].replace(pe_type_mapping)
split_label['pe_type'].fillna(0, inplace=True)
# Out:
# C:\Users\cheek\AppData\Local\Temp\ipykernel_32604\3768595702.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_label.loc[:, 'pe_type'] = split_label['pe_type'].replace(pe_type_mapping)
# C:\Users\cheek\AppData\Local\Temp\ipykernel_32604\3768595702.py:7: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   split_label.loc[:, 'pe_type'] = split_label['pe_type'].replace(pe_type_mapping)
# C:\Users\cheek\AppData\Local\Temp\ipykernel_32604\3768595702.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   split_label['pe_type'].fillna(0, inplace=True)

# %%
X_train = df_top_features[split_label['split'] == 'train']
y_train = split_label[split_label['split'] == 'train']['pe_type']

X_val = df_top_features[split_label['split'] == 'val']
y_val = split_label[split_label['split'] == 'val']['pe_type']

X_test = df_top_features[split_label['split'] == 'test']
y_test = split_label[split_label['split'] == 'test']['pe_type']

# %%
print(y_train.value_counts())
# Out:
# 0.0    2025
# 1.0     967
# Name: pe_type, dtype: int64

# %%
offending_columns = [col for col in X_train.columns if any(char in col for char in ['[', ']', '<'])]

print(offending_columns)

X_train = X_train.rename(columns={col: col.replace('[', '').replace(']', '').replace('<', '') for col in offending_columns})
X_val = X_val.rename(columns={col: col.replace('[', '').replace(']', '').replace('<', '') for col in offending_columns})
# Out:
# []

# %%
import catboost
from catboost import CatBoostClassifier, Pool

# %%
train_data = Pool(data=X_train, label=y_train)
val_data = Pool(data=X_val, label=y_val)

params = {
    'iterations': 100,
    'learning_rate': 0.1,
    'depth': 6,
    'loss_function': 'MultiClass',
    'eval_metric': 'MultiClass',
    'verbose': 10  # Display results every 10 iterations
}

train_data = Pool(data=X_train, label=y_train)
val_data = Pool(data=X_val, label=y_val)
test_data = Pool(data=X_test, label=y_test)

model = CatBoostClassifier(**params)
model.fit(train_data, eval_set=[val_data, test_data], early_stopping_rounds=10)
# Out:
# 0:	learn: 0.6379199	test: 0.6694877	test1: 0.7188894	best: 0.7188894 (0)	total: 10.6ms	remaining: 1.05s
# 10:	learn: 0.3381079	test: 0.4927425	test1: 1.0078352	best: 0.7188894 (0)	total: 40ms	remaining: 324ms
# Stopped by overfitting detector  (10 iterations wait)
#
# bestTest = 0.7188894425
# bestIteration = 0
#
# Shrink model to first 1 iterations.

# %%
import matplotlib.pyplot as plt

train_loss = model.get_evals_result()['learn']['MultiClass']
val_loss = model.get_evals_result()['validation_0']['MultiClass']
test_loss = model.get_evals_result()['validation_1']['MultiClass']

plt.figure(figsize=(12, 5))
plt.plot(train_loss, label="Train Loss")
plt.plot(val_loss, label="Validation Loss")
plt.plot(test_loss, label="Test Loss")
plt.xlabel("Iterations")
plt.ylabel("Loss")
plt.legend()
plt.title("Loss Over Iterations")
plt.show()

# %%
from sklearn.metrics import accuracy_score

train_preds = model.predict(X_train).reshape(-1)
val_preds = model.predict(X_val).reshape(-1)
test_preds = model.predict(X_test).reshape(-1)





test_accuracy = accuracy_score(y_test, test_preds)
train_accuracy = accuracy_score(y_train, train_preds)
val_accuracy = accuracy_score(y_val, val_preds)

print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
print(f"Training Accuracy: {train_accuracy * 100:.2f}%")
print(f"Validation Accuracy: {val_accuracy * 100:.2f}%")
# Out:
# Test Accuracy: 51.94%
# Training Accuracy: 83.39%
# Validation Accuracy: 91.41%

# %%
feature_importances = model.get_feature_importance()
feature_names = X_train.columns
for feature, importance in zip(feature_names, feature_importances):
    print(f"{feature}: {importance:.2f}")
# Out:
# OTHER PREGNANCY WITH ABORTIVE OUTCOME:presence: 0.00
#  NONINFECTIOUS ENTERITIS AND COLITIS:presence: 0.00
# INJURY TO BLOOD VESSELS:frequency: 0.00
# ANALGESICS, NARCOTICS:Frequeny: 0.00
# Other congenital anomalies of digestive system:presence: 0.00
# Congenital anomalies of the integument:frequency: 0.00
#  ECTOPIC AND MOLAR PREGNANCY:frequency: 0.00
# COMPLICATIONS MAINLY RELATED TO PREGNANCY:frequency: 0.00
#  OTHER FORMS OF HEART DISEASE:frequency: 0.00
# DISORDERS OF THE EYE AND ADNEXA:frequency: 0.00
# wbc:Binary: 0.00
# COMPLICATIONS MAINLY RELATED TO PREGNANCY:presence: 0.00
# OTHER DISEASES OF SKIN AND SUBCUTANEOUS TISSUE:frequency: 0.00
# DISEASES OF PULMONARY CIRCULATION:presence: 85.90
#  INFLAMMATORY DISEASES OF THE CENTRAL NERVOUS SYSTEM:frequency: 0.00
# Outpatient_MONOAMINE OXIDASE (MAO) INHIBITOR ANTIDEPRESSANTS:Frequeny: 0.00
# ANTIVIRALS, HIV-SPECIFIC, CCR5 CO-RECEPTOR ANTAG.:Binary: 0.00
# RENIN INHIBITOR,DIRECT-ANGIOTENSIN RECEPTR ANTAGON:Frequeny: 0.00
# ANTINEOPLASTIC - EPOTHILONES AND ANALOGS:Frequeny: 0.00
# Outpatient_THICKENING AGENTS, ORAL:Frequeny: 0.00
# Outpatient_SELECTIVE SEROTONIN 5-HT2A INVERSE AGONISTS (SSIA):Binary: 0.00
# INTERNAL INJURY OF THORAX, ABDOMEN, AND PELVIS:frequency: 0.00
# OPEN WOUNDS:frequency: 0.00
# lactate:Value: 0.00
# TOXIC EFFECTS OF SUBSTANCES CHIEFLY NONMEDICINAL AS TO SOURCE:frequency: 0.00
# hemoglobin:Value: 0.00
# ANTIDIARRHEAL MICROORGANISMS AGENTS:Binary: 0.00
# OTHER CONDITIONS ORIGINATING IN THE PERINATAL PERIOD:presence: 0.00
#  OTHER DISEASES OF DIGESTIVE SYSTEM:presence: 0.00
# Native American: 0.00
#  OTHER DISEASES OF DIGESTIVE SYSTEM:frequency: 0.00
# FOLIC ACID PREPARATIONS:Binary: 0.00
# VANCOMYCIN AND DERIVATIVES:Binary: 0.00
# POLIOMYELITIS AND OTHER NON-ARTHROPOD-BORNE VIRAL DISEASES AND PRION DISEASES OF CENTRAL NERVOUS SYSTEM:presence: 0.00
# OTHER CONDITIONS ORIGINATING IN THE PERINATAL PERIOD:frequency: 0.00
# EYE ANTI-INFLAMMATORY AGENTS:Binary: 0.00
# ARV-NUCLEOSIDE,NUCLEOTIDE RTI,INTEGRASE INHIBITORS:Frequeny: 0.00
#  DISEASES OF OTHER ENDOCRINE GLANDS:presence: 0.00
# INTESTINAL MOTILITY STIMULANTS:Binary: 0.00
# THROMBOLYTIC ENZYMES:Binary: 0.00
# OPEN WOUNDS:presence: 0.00
# ANTINEOPLASTIC - MEK1 AND MEK2 KINASE INHIBITORS:Binary: 0.00
# INFLAMMATORY DISEASE OF FEMALE PELVIC ORGANS:presence: 0.00
# Outpatient_OPHTH. VEGF-A RECEPTOR ANTAG. RCMB MC ANTIBODY:Binary: 0.00
# DURABLE MEDICAL EQUIPMENT,MISCELLANEOUS:Binary: 0.00
# TOPICAL AGENTS,MISCELLANEOUS:Binary: 0.00
# Outpatient_IMMUNOMODULATOR,B-LYMPHOCYTE STIM(BLYS)-SPEC INHIB:Frequeny: 0.00
# TOPICAL ANTIPARASITICS:Binary: 0.00
# Outpatient_HEPATITIS C TREATMENT AGENTS:Frequeny: 0.00
# OPHTHALMIC ANTI-INFLAMMATORY IMMUNOMODULATOR-TYPE:Binary: 0.00
# VIRAL/TUMORIGENIC VACCINES:Binary: 0.00
# ANTITHYROID PREPARATIONS:Binary: 0.00
# THROMBIN INHIBITORS,SEL,DIRECT,REVERS-HIRUDIN TYPE:Binary: 0.00
# VAGINAL ANTIFUNGALS:Binary: 0.00
# Outpatient_TOPICAL HEMOSTATICS:Binary: 0.00
# Outpatient_GENERAL INHALATION AGENTS:Binary: 0.00
# ANTIVIRALS, HIV-SPEC, NON-PEPTIDIC PROTEASE INHIB:Binary: 0.00
# Outpatient_COAGULANTS:Binary: 0.00
# VASODILATORS, COMBINATION:Binary: 0.00
# ANTINEOPLASTIC - IMMUNOTHERAPY, THERAPEUTIC VAC:Binary: 0.00
# CYTOTOXIC T-LYMPHOCYTE ANTIGEN(CTLA-4)RMC ANTIBODY:Binary: 0.00
# Outpatient_FACTOR IX PREPARATIONS:Binary: 0.00
# Outpatient_MU-OPIOID RECEPTOR ANTAGONISTS,PERIPHERALLY-ACTING:Binary: 0.00
# HEPATIC DIAGNOSTICS:Binary: 0.00
# VITAMIN E PREPARATIONS:Binary: 0.00
# current_age_yrs: 0.00
# VITAMIN B PREPARATIONS:Binary: 0.00
# ANTINEOPLASTIC LHRH(GNRH) AGONIST,PITUITARY SUPPR.:Binary: 0.00
# Outpatient_URINARY TRACT ANALGESIC AGENTS:Binary: 0.00
# VITAMIN A DERIVATIVES:Binary: 0.00
# Outpatient_CHRONIC INFLAM. COLON DX, 5-A-SALICYLAT,RECTAL TX:Binary: 0.00
# VITAMIN K PREPARATIONS:Binary: 0.00
# OSMOTIC DIURETICS:Binary: 0.00
# ANTIPSYCHOTIC,ATYPICAL,DOPAMINE,SEROTONIN ANTAGNST:Binary: 12.60
# THYROID HORMONES:Binary: 0.00
# NITROFURAN DERIVATIVES ANTIBACTERIAL AGENTS:Binary: 0.00
# CHOLINESTERASE INHIBITORS:Binary: 0.00
# BULK CHEMICALS:Binary: 0.00
# ANALGESIC,NON-SALICYLATE,BARBITURATE,XANTHINE COMB:Binary: 0.00
# Outpatient_BARBITURATES:Binary: 0.00
# Outpatient_BENZODIAZEPINES:Frequeny: 0.00
# BETA-ADRENERGIC AGENTS, INHALED, SHORT ACTING:Binary: 0.00
# Outpatient_CXCR4 CHEMOKINE RECEPTOR ANTAGONIST:Binary: 0.00
# APPETITE STIM. FOR ANOREXIA,CACHEXIA,WASTING SYND.:Binary: 0.00
# Outpatient_BILE SALT SEQUESTRANTS:Binary: 0.00
# IV FAT EMULSIONS:Binary: 0.00
# ANTINEOPLAST,HISTONE DEACETYLASE (HDAC) INHIBITORS:Binary: 0.00
# EYE ANTIHISTAMINES:Binary: 0.00
# ANAPHYLAXIS THERAPY AGENTS:Binary: 0.00
# Outpatient_ANTI-PROGRAMMED CELL DEATH-LIGAND 1 (PD-L1) MAB:Binary: 0.00
# Outpatient_NON-NARC ANTITUS-1ST GEN ANTIHIST-DECON-ANALGESIC:Frequeny: 0.00
# VITAMIN B6 PREPARATIONS:Binary: 0.00
# ANTINEOPLASTIC - MTOR KINASE INHIBITORS:Frequeny: 0.00
# DIAGNOSTIC PREPARATIONS,MISCELLANEOUS:Binary: 0.00
# Outpatient_EYE ANTIHISTAMINES:Binary: 0.00
# UTERINE RADIOPAQUE DIAGNOSTIC AGENTS:Binary: 0.00
# EAR PREPARATIONS,ANTIBIOTICS:Binary: 0.00
# TOPICAL/MUCOUS MEMBR./SUBCUT. ENZYMES:Binary: 0.00
# CHOLERETICS:Binary: 0.00
# Outpatient_ANGIOTENSIN RECEPT-NEPRILYSIN INHIBITOR COMB(ARNI):Frequeny: 0.00
# Outpatient_PLATELET REDUCING AGENTS:Binary: 0.00
# Outpatient_Analgesics-nonnarcotic:Frequeny: 0.00
# INTRA-UTERINE DEVICES (IUDS):Binary: 0.00
# ANTHELMINTICS:Binary: 0.00
# VENOSCLEROSING AGENTS:Binary: 0.00
# ANAPHYLAXIS THERAPY AGENTS:Frequeny: 0.00
# BLOOD SUGAR DIAGNOSTICS:Frequeny: 0.00
# TOPICAL/MUCOUS MEMBR./SUBCUT. ENZYMES:Frequeny: 0.00
# MOUTHWASHES:Frequeny: 0.00
# PARENTERAL AMINO ACID SOLUTIONS AND COMBINATIONS:Frequeny: 0.08
# DIRECT FACTOR XA INHIBITORS:Frequeny: 0.00
# 1ST GEN ANTIHISTAMINE AND DECONGESTANT COMBINATION:Frequeny: 0.00
# MU-OPIOID RECEPTOR ANTAGONISTS,PERIPHERALLY-ACTING:Frequeny: 0.00
# LEUKOCYTE (WBC) STIMULANTS:Frequeny: 0.00
# ANTI-OBESITY - ANOREXIC AGENTS:Frequeny: 0.00
# ALLERGENIC EXTRACTS, THERAPEUTIC:Frequeny: 0.00
# Outpatient_PLATELET REDUCING AGENTS:Frequeny: 0.00
# Outpatient_GENERAL INHALATION AGENTS:Frequeny: 0.00
# MONOCLONAL ANTIBODY - INTERLEUKIN-5 ANTAGONISTS:Frequeny: 0.00
# BONE RESORPTION INHIBITORS:Frequeny: 0.00
# VITAMIN B2 PREPARATIONS:Frequeny: 0.00
# BETA-BLOCKERS AND THIAZIDE,THIAZIDE-LIKE DIURETICS:Frequeny: 0.00
# EAR PREPARATIONS,EAR WAX REMOVERS:Frequeny: 0.00
# EAR PREPARATIONS,LOCAL ANESTHETICS:Frequeny: 0.00
# IBS-C/CIC AGENTS, GUANYLATE CYCLASE-C AGONIST:Frequeny: 0.00
# ANTIHYPERGLY,INCRETIN MIMETIC(GLP-1 RECEP.AGONIST):Frequeny: 0.00
# Outpatient_ANTIBIOTICS, MISCELLANEOUS, OTHER:Frequeny: 0.00
# ANTI-ALCOHOLIC PREPARATIONS:Frequeny: 0.00
# TOPICAL VIT D ANALOG/ANTI-INFLAMMATORY STEROID:Frequeny: 0.00
# MONOCLONAL ANTIBODIES TO IMMUNOGLOBULIN E (IGE):Frequeny: 0.00
# GERIATRIC VITAMIN PREPARATIONS:Frequeny: 0.00
# ANTI-MYCOBACTERIUM AGENTS:Frequeny: 0.00
# 2ND GEN ANTIHISTAMINE AND DECONGESTANT COMBINATION:Frequeny: 0.00
# VIRAL/TUMORIGENIC VACCINES:Frequeny: 0.00
# ARTV NUCLEOSIDE,NUCLEOTIDE,NON-NUCLEOSIDE RTI COMB:Frequeny: 0.00
# INTERLEUKIN-6 (IL-6) RECEPTOR INHIBITORS:Frequeny: 0.00
# BENZODIAZEPINES:Frequeny: 0.00
# NASAL MAST CELL STABILIZERS:Frequeny: 0.00
# ANTIPERSPIRANTS:Frequeny: 0.00
# PHARMACEUTICAL ADJUVANTS,TABLET,CAPSULE COMPONENTS:Frequeny: 0.00
# HEPARIN AND RELATED PREPARATIONS:Frequeny: 0.00
# ANTIFUNGAL AGENTS:Binary: 0.00
# ANTIHYPERGLYCEMIC, AMYLIN ANALOG-TYPE:Binary: 0.00
# ALLERGENIC EXTRACTS, THERAPEUTIC:Binary: 0.00
# PREGNANCY MAINTAINING AGENT,HORMONAL:Binary: 0.00
# BETA-ADRENERGIC AGENTS, INHALED, ULTRA-LONG ACTING:Binary: 0.00
# METABOLIC FUNCTION DIAGNOSTICS:Binary: 0.00
# ESTROGEN/ANDROGEN COMBINATIONS:Binary: 0.00
# ANTIVIRAL MONOCLONAL ANTIBODIES:Binary: 0.00
# NARCOTIC AND SALICYLATE ANALGESICS,BARBIT,XANTHINE:Binary: 0.00
# Outpatient_DECONGESTANT-EXPECTORANT COMBINATIONS:Frequeny: 0.00
# ORAL MUCOSITIS/STOMATITIS AGENTS:Binary: 0.00
# NUTRITIONAL THERAPY, MED COND SPECIAL FORMULATION:Binary: 0.00
# ARTV NUCLEOSIDE,NUCLEOTIDE,NON-NUCLEOSIDE RTI COMB:Binary: 0.00
# THROMBOPOIETIN RECEPTOR AGONISTS:Binary: 0.00
# Outpatient_GLYCYLCYCLINES:Frequeny: 0.00
# NARCOTIC,NON-SALICY.ANALGESIC,BARBITURATE,XANTHINE:Binary: 0.00
# Outpatient_CALCIUM CHANNEL BLOCKING AGENTS:Binary: 0.00
# CONTACT LENS PREPARATIONS(GAS,HARD,SOFT):Frequeny: 0.00
# RENIN INHIBITOR,DIRECT-ANGIOTENSIN RECEPTR ANTAGON:Binary: 0.00
# ACNE AGENTS,SYSTEMIC:Binary: 0.00
# ALZHEIMER'S THX,NMDA RECEPTOR ANTAG-CHOLINES INHIB:Binary: 0.00
# Outpatient_WATER:Frequeny: 0.00
# NASAL WASHES:Frequeny: 0.00
# Outpatient_GENERAL BRONCHODILATOR AGENTS:Frequeny: 0.00
# ABORTIFACIENT-PROGESTERONE RECEPTOR ANTAGONISTS:Binary: 0.00
# NEEDLES/NEEDLELESS DEVICES:Binary: 0.00
# OSTOMY SUPPLIES:Binary: 0.00
# ANTIFUNGAL-LOCAL ANESTHETIC-ANTIHISTAMINE COMB:Binary: 0.00
# PHARMACEUTICAL ADJUVANTS,TABLET,CAPSULE COMPONENTS:Binary: 0.00
# ANTINEOPLASTIC - VEGF-A,B AND PLGF INHIBITORS:Binary: 0.00
# SMOKING DETERRENTS, OTHER:Binary: 0.00
# ANTISEPTICS,MISCELLANEOUS:Binary: 0.00
# HEPATITIS C VIRUS - NS5A REPLICATION COMPLEX INHIB:Binary: 0.00
# Outpatient_ANALGESIC/ANTIPYRETICS,NON-SALICYLATE:Frequeny: 0.00
# Outpatient_EAR PREPARATIONS,ANTIBIOTICS:Binary: 0.00
# ABSORBABLE SULFONAMIDE ANTIBACTERIAL AGENTS:Binary: 0.00
# MYCOSES:presence: 0.00
#  OTHER BACTERIAL DISEASES:presence: 0.00
# Outpatient_ACE INHIBITOR-CALCIUM CHANNEL BLOCKER COMBINATION:Binary: 0.00
# SYPHILIS AND OTHER VENEREAL DISEASES:presence: 0.00
# OTHER DISEASES OF THE UPPER RESPIRATORY TRACT:frequency: 0.00
# Outpatient_PANTHENOL PREPARATIONS:Binary: 0.00
#  OTHER HEADACHE SYNDROMES:frequency: 0.00
# POISONING BY DRUGS, MEDICINAL AND BIOLOGICAL SUBSTANCES:presence: 0.00
# Outpatient_NEEDLES/NEEDLELESS DEVICES:Frequeny: 0.00
# Outpatient_JANUS KINASE (JAK) INHIBITORS:Binary: 0.00
# DISORDERS OF THE PERIPHERAL NERVOUS SYSTEM:frequency: 0.00
# Symptoms involving nervous and musculoskeletal systems:presence: 0.00
#  SUPPLEMENTARY CLASSIFICATION OF EXTERNAL CAUSES OF INJURY AND POISONING:presence: 0.00
# alk:Binary: 0.00
# Outpatient_ANGIOTEN.RECEPTR ANTAG-CALCIUM CHANL BLKR-THIAZIDE:Binary: 0.00
# inr:Binary: 0.00
# ptt:Binary: 0.00
# alk:Value: 0.00
#  OTHER DISEASES OF URINARY SYSTEM:frequency: 0.00
#  NONINFECTIOUS ENTERITIS AND COLITIS:frequency: 0.00
# calcium:Value: 0.00
# DISEASES OF ESOPHAGUS, STOMACH, AND DUODENUM:frequency: 1.43
# Outpatient_SOLVENTS:Binary: 0.00

# %%
import shap

explainer = shap.Explainer(model)
shap_values = explainer(X_train)

shap.summary_plot(shap_values, X_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\cheek\Desktop\GT\7644\proj\tabular-cat.ipynb Cell 31 line 6
#       <a href='vscode-notebook-cell:/c%3A/Users/cheek/Desktop/GT/7644/proj/tabular-cat.ipynb#X51sZmlsZQ%3D%3D?line=2'>3</a> explainer = shap.Explainer(model)
#       <a href='vscode-notebook-cell:/c%3A/Users/cheek/Desktop/GT/7644/proj/tabular-cat.ipynb#X51sZmlsZQ%3D%3D?line=3'>4</a> shap_values = explainer(X_train)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/cheek/Desktop/GT/7644/proj/tabular-cat.ipynb#X51sZmlsZQ%3D%3D?line=5'>6</a> shap.summary_plot(shap_values, X_train)
#
# File c:\Users\cheek\miniconda3\lib\site-packages\shap\plots\_beeswarm.py:595, in summary_legacy(shap_values, features, feature_names, max_display, plot_type, color, axis_color, title, alpha, show, sort, color_bar, plot_size, layered_violin_max_num_bins, class_names, class_inds, color_bar_label, cmap, show_values_in_legend, auto_size_plot, use_log_scale)
#     591 proj_shap_values = shap_values[:, sort_inds[0], sort_inds]
#     592 proj_shap_values[:, 1:] *= 2  # because off diag effects are split in half
#     593 summary_legacy(
#     594     proj_shap_values, features[:, sort_inds] if features is not None else None,
# --> 595     feature_names=feature_names[sort_inds],
#     596     sort=False, show=False, color_bar=False,
#     597     plot_size=None,
#     598     max_display=max_display
#     599 )
#     600 pl.xlim((slow, shigh))
#     601 pl.xlabel("")
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
model.plot_tree(tree_idx=0, pool=train_data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File c:\Users\cheek\miniconda3\lib\site-packages\graphviz\backend\execute.py:79, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      78         kwargs['stdout'] = kwargs['stderr'] = subprocess.PIPE
# ---> 79     proc = _run_input_lines(cmd, input_lines, kwargs=kwargs)
#      80 else:
#
# File c:\Users\cheek\miniconda3\lib\site-packages\graphviz\backend\execute.py:99, in _run_input_lines(cmd, input_lines, kwargs)
#      98 def _run_input_lines(cmd, input_lines, *, kwargs):
# ---> 99     popen = subprocess.Popen(cmd, stdin=subprocess.PIPE, **kwargs)
#     101     stdin_write = popen.stdin.write
#
# File c:\Users\cheek\miniconda3\lib\subprocess.py:971, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
#     968             self.stderr = io.TextIOWrapper(self.stderr,
#     969                     encoding=encoding, errors=errors)
# --> 971     self._execute_child(args, executable, preexec_fn, close_fds,
#     972                         pass_fds, cwd, env,
#     973                         startupinfo, creationflags, shell,
#     974                         p2cread, p2cwrite,
#     975                         c2pread, c2pwrite,
#     976                         errread, errwrite,
#     977                         restore_signals,
#     978                         gid, gids, uid, umask,
#     979                         start_new_session)
#     980 except:
#     981     # Cleanup if the child failed starting.
#
# File c:\Users\cheek\miniconda3\lib\subprocess.py:1440, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session)
#    1439 try:
# -> 1440     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1441                              # no special security
#    1442                              None, None,
#    1443                              int(not close_fds),
#    1444                              creationflags,
#    1445                              env,
#    1446                              cwd,
#    1447                              startupinfo)
#    1448 finally:
#    1449     # Child is launched. Close the parent's copy of those pipe
#    1450     # handles that only the child should have open.  You need
#    (...)
#    1453     # pipe will not close when the child process exits and the
#    1454     # ReadFile will hang.
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# The above exception was the direct cause of the following exception:
#
# ExecutableNotFound                        Traceback (most recent call last)
# File c:\Users\cheek\miniconda3\lib\site-packages\IPython\core\formatters.py:974, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#     971     method = get_real_method(obj, self.print_method)
#     973     if method is not None:
# --> 974         return method(include=include, exclude=exclude)
#     975     return None
#     976 else:
#
# File c:\Users\cheek\miniconda3\lib\site-packages\graphviz\jupyter_integration.py:98, in JupyterIntegration._repr_mimebundle_(self, include, exclude, **_)
#      96 include = set(include) if include is not None else {self._jupyter_mimetype}
#      97 include -= set(exclude or [])
# ---> 98 return {mimetype: getattr(self, method_name)()
#      99         for mimetype, method_name in MIME_TYPES.items()
#     100         if mimetype in include}
#
# File c:\Users\cheek\miniconda3\lib\site-packages\graphviz\jupyter_integration.py:98, in <dictcomp>(.0)
#      96 include = set(include) if include is not None else {self._jupyter_mimetype}
#      97 include -= set(exclude or [])
# ---> 98 return {mimetype: getattr(self, method_name)()
#      99         for mimetype, method_name in MIME_TYPES.items()
#     100         if mimetype in include}
#
# File c:\Users\cheek\miniconda3\lib\site-packages\graphviz\jupyter_integration.py:112, in JupyterIntegration._repr_image_svg_xml(self)
#     110 def _repr_image_svg_xml(self) -> str:
#     111     """Return the rendered graph as SVG string."""
# --> 112     return self.pipe(format='svg', encoding=SVG_ENCODING)
#
# File c:\Users\cheek\miniconda3\lib\site-packages\graphviz\piping.py:104, in Pipe.pipe(self, format, renderer, formatter, neato_no_op, quiet, engine, encoding)
#      55 def pipe(self,
#      56          format: typing.Optional[str] = None,
#      57          renderer: typing.Optional[str] = None,
#    (...)
#      61          engine: typing.Optional[str] = None,
#      62          encoding: typing.Optional[str] = None) -> typing.Union[bytes, str]:
#      63     """Return the source piped through the Graphviz layout command.
#      64
#      65     Args:
#    (...)
#     102         '<?xml version='
#     103     """
# --> 104     return self._pipe_legacy(format,
#     105                              renderer=renderer,
#     106                              formatter=formatter,
#     107                              neato_no_op=neato_no_op,
#     108                              quiet=quiet,
#     109                              engine=engine,
#     110                              encoding=encoding)
#
# File c:\Users\cheek\miniconda3\lib\site-packages\graphviz\_tools.py:171, in deprecate_positional_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     162     wanted = ', '.join(f'{name}={value!r}'
#     163                        for name, value in deprecated.items())
#     164     warnings.warn(f'The signature of {func.__name__} will be reduced'
#     165                   f' to {supported_number} positional args'
#     166                   f' {list(supported)}: pass {wanted}'
#     167                   ' as keyword arg(s)',
#     168                   stacklevel=stacklevel,
#     169                   category=category)
# --> 171 return func(*args, **kwargs)
#
# File c:\Users\cheek\miniconda3\lib\site-packages\graphviz\piping.py:121, in Pipe._pipe_legacy(self, format, renderer, formatter, neato_no_op, quiet, engine, encoding)
#     112 @_tools.deprecate_positional_args(supported_number=2)
#     113 def _pipe_legacy(self,
#     114                  format: typing.Optional[str] = None,
#    (...)
#     119                  engine: typing.Optional[str] = None,
#     120                  encoding: typing.Optional[str] = None) -> typing.Union[bytes, str]:
# --> 121     return self._pipe_future(format,
#     122                              renderer=renderer,
#     123                              formatter=formatter,
#     124                              neato_no_op=neato_no_op,
#     125                              quiet=quiet,
#     126                              engine=engine,
#     127                              encoding=encoding)
#
# File c:\Users\cheek\miniconda3\lib\site-packages\graphviz\piping.py:149, in Pipe._pipe_future(self, format, renderer, formatter, neato_no_op, quiet, engine, encoding)
#     146 if encoding is not None:
#     147     if codecs.lookup(encoding) is codecs.lookup(self.encoding):
#     148         # common case: both stdin and stdout need the same encoding
# --> 149         return self._pipe_lines_string(*args, encoding=encoding, **kwargs)
#     150     try:
#     151         raw = self._pipe_lines(*args, input_encoding=self.encoding, **kwargs)
#
# File c:\Users\cheek\miniconda3\lib\site-packages\graphviz\backend\piping.py:212, in pipe_lines_string(engine, format, input_lines, encoding, renderer, formatter, neato_no_op, quiet)
#     206 cmd = dot_command.command(engine, format,
#     207                           renderer=renderer,
#     208                           formatter=formatter,
#     209                           neato_no_op=neato_no_op)
#     210 kwargs = {'input_lines': input_lines, 'encoding': encoding}
# --> 212 proc = execute.run_check(cmd, capture_output=True, quiet=quiet, **kwargs)
#     213 return proc.stdout
#
# File c:\Users\cheek\miniconda3\lib\site-packages\graphviz\backend\execute.py:84, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      82 except OSError as e:
#      83     if e.errno == errno.ENOENT:
# ---> 84         raise ExecutableNotFound(cmd) from e
#      85     raise
#      87 if not quiet and proc.stderr:
#
# ExecutableNotFound: failed to execute WindowsPath('dot'), make sure the Graphviz executables are on your systems' PATH

# %%
interaction = model.get_feature_importance(data=train_data, type='Interaction')
interaction
# Out:
# array([[ 13.        , 109.        ,  19.20634921],
#        [ 13.        , 198.        ,  18.25396825],
#        [ 73.        , 109.        ,  16.98412698],
#        [ 13.        ,  73.        ,  16.66666667],
#        [ 73.        , 198.        ,  16.66666667],
#        [109.        , 198.        ,  12.22222222]])
